# %%
#simply printing hello world
a= "Hello World"
print(a)
# Out:
# Hello World

# %%
#Length measuring
a= "Hello World"
print(a[4])
print(len(a))
# Out:
# o
# 11

# %%
#string check
#slicing strings
a= "I am Prakriti"
print (a[8:12])
# Out:
# krit

# %%
#modification of strings
a= "Hello World"
print(a.upper)
# Out:
# <built-in method upper of str object at 0x7bbff1e7b2f0>

# %%
# Duplicate values will overwrite existing values
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "year": 2020
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}
